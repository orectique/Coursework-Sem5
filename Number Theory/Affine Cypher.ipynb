# %%
text = 'LREKMEPQOCPCBOYGYWPPEHFIWPFZYQGDZERGYPWFYWECYOJEQCMYEGFGYPWFCYMJYFGFMFGWPQGDZERGPGFFZEYCIEDBCGPFEHFBEFFERQCPJEEPQRODFEXFWCPOWPEWLYETERCBXGLLEREPFQGDZERFEHFBEFFERYXEDEPXGPSWPGFYDWYGFGWPGPFZEIEYYCSE'

# %%
corpus = list(text)

# %%
corpus
# Out:
# ['L',
#  'R',
#  'E',
#  'K',
#  'M',
#  'E',
#  'P',
#  'Q',
#  'O',
#  'C',
#  'P',
#  'C',
#  'B',
#  'O',
#  'Y',
#  'G',
#  'Y',
#  'W',
#  'P',
#  'P',
#  'E',
#  'H',
#  'F',
#  'I',
#  'W',
#  'P',
#  'F',
#  'Z',
#  'Y',
#  'Q',
#  'G',
#  'D',
#  'Z',
#  'E',
#  'R',
#  'G',
#  'Y',
#  'P',
#  'W',
#  'F',
#  'Y',
#  'W',
#  'E',
#  'C',
#  'Y',
#  'O',
#  'J',
#  'E',
#  'Q',
#  'C',
#  'M',
#  'Y',
#  'E',
#  'G',
#  'F',
#  'G',
#  'Y',
#  'P',
#  'W',
#  'F',
#  'C',
#  'Y',
#  'M',
#  'J',
#  'Y',
#  'F',
#  'G',
#  'F',
#  'M',
#  'F',
#  'G',
#  'W',
#  'P',
#  'Q',
#  'G',
#  'D',
#  'Z',
#  'E',
#  'R',
#  'G',
#  'P',
#  'G',
#  'F',
#  'F',
#  'Z',
#  'E',
#  'Y',
#  'C',
#  'I',
#  'E',
#  'D',
#  'B',
#  'C',
#  'G',
#  'P',
#  'F',
#  'E',
#  'H',
#  'F',
#  'B',
#  'E',
#  'F',
#  'F',
#  'E',
#  'R',
#  'Q',
#  'C',
#  'P',
#  'J',
#  'E',
#  'E',
#  'P',
#  'Q',
#  'R',
#  'O',
#  'D',
#  'F',
#  'E',
#  'X',
#  'F',
#  'W',
#  'C',
#  'P',
#  'O',
#  'W',
# ...
